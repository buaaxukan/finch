# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="img/self_attn.png" width="200">

# %%
"""
pip3 install tensor2tensor
"""
import tensorflow as tf
import numpy as np
from tensor2tensor.utils import beam_search

# %%
params = {
    'batch_size': 64,
    'text_iter_step': 25,
    'seq_len': 200,
    'hidden_dim': 128,
    'num_head': 8,
    'n_hidden_layer': 2,
    'display_step': 10,
    'generate_step': 100,
    'beam_size': 5,
}

# %%
def parse_text(file_path):
    with open(file_path) as f:
        text = f.read()
    
    char2idx = {c: i+3 for i, c in enumerate(set(text))}
    char2idx['<pad>'] = 0
    char2idx['<start>'] = 1
    char2idx['<end>'] = 2
    
    ints = np.array([char2idx[char] for char in list(text)])
    return ints, char2idx

def next_batch(ints):
    len_win = params['seq_len'] * params['batch_size']
    for i in range(0, len(ints)-len_win, params['text_iter_step']):
        clip = ints[i: i+len_win]
        yield clip.reshape([params['batch_size'], params['seq_len']])
        
def input_fn(ints):
    dataset = tf.data.Dataset.from_generator(
        lambda: next_batch(ints), tf.int32, tf.TensorShape([None, params['seq_len']]))
    iterator = dataset.make_one_shot_iterator()
    return iterator.get_next()

# %%
def start_sent(x):
    _x = tf.fill([tf.shape(x)[0], 1], params['char2idx']['<start>'])
    return tf.concat([_x, x], 1)

def end_sent(x):
    _x = tf.fill([tf.shape(x)[0], 1], params['char2idx']['<end>'])
    return tf.concat([x, _x], 1)

def embed_seq(x, vocab_sz, embed_dim, name, zero_pad=False, scale=False):
    embedding = tf.get_variable(name, [vocab_sz, embed_dim])
    if zero_pad:
        embedding = tf.concat([tf.zeros([1, embed_dim]), embedding[1:, :]], 0)
    x = tf.nn.embedding_lookup(embedding, x)
    if scale:
        x = x * np.sqrt(embed_dim)
    return x

def position_encoding(inputs):
    repr_dim = inputs.get_shape()[-1].value
    pos = tf.reshape(tf.range(0.0, tf.to_float(tf.shape(inputs)[1]), dtype=tf.float32), [-1, 1])
    i = np.arange(0, repr_dim, 2, np.float32)
    denom = np.reshape(np.power(10000.0, i / repr_dim), [1, -1])
    enc = tf.expand_dims(tf.concat([tf.sin(pos / denom), tf.cos(pos / denom)], 1), 0)
    return tf.tile(enc, [tf.shape(inputs)[0], 1, 1])

def layer_norm(inputs, epsilon=1e-8):
    mean, variance = tf.nn.moments(inputs, [-1], keep_dims=True)
    normalized = (inputs - mean) / (tf.sqrt(variance + epsilon))
    
    params_shape = inputs.get_shape()[-1:]
    gamma = tf.get_variable('gamma', params_shape, tf.float32, tf.ones_initializer())
    beta = tf.get_variable('beta', params_shape, tf.float32, tf.zeros_initializer())
    
    return gamma * normalized + beta

def self_attention(inputs, is_training, activation=None):
    num_units = params['hidden_dim']
    num_heads = params['num_head']
    T_q = T_k = tf.shape(inputs)[1]

    Q_K_V = tf.layers.dense(inputs, 3*num_units, activation)
    Q, K, V = tf.split(Q_K_V, 3, -1)
    Q_ = tf.concat(tf.split(Q, num_heads, axis=2), 0)                         
    K_ = tf.concat(tf.split(K, num_heads, axis=2), 0)                        
    V_ = tf.concat(tf.split(V, num_heads, axis=2), 0)                         

    align = tf.matmul(Q_, tf.transpose(K_, [0,2,1]))                               
    align = align / np.sqrt(K_.get_shape().as_list()[-1])

    paddings = tf.fill(tf.shape(align), float('-inf'))         
    lower_tri = tf.ones([T_q, T_k])                                                
    lower_tri = tf.linalg.LinearOperatorLowerTriangular(lower_tri).to_dense()      
    masks = tf.tile(tf.expand_dims(lower_tri,0), [tf.shape(align)[0],1,1])       
    align = tf.where(tf.equal(masks, 0), paddings, align)               

    align = tf.nn.softmax(align)                                                  
    align = tf.layers.dropout(align, 0.1, training=is_training)           
    x = tf.matmul(align, V_)                                                 
    x = tf.concat(tf.split(x, num_heads, axis=0), 2)              
    x += inputs                                                                
    x = layer_norm(x)                                                 
    return x

def ffn(inputs, activation=tf.nn.relu):
    x = tf.layers.conv1d(inputs, 4*params['hidden_dim'], 1, activation=activation)
    x = tf.layers.conv1d(x, params['hidden_dim'], 1, activation=None)
    x += inputs
    x = layer_norm(x)
    return x

# %%
def forward(inputs, reuse, is_training):
    with tf.variable_scope('model', reuse=reuse):
        x = embed_seq(inputs, params['vocab_size'], params['hidden_dim'], 'word_embedding',
                      zero_pad=True, scale=True)
        x += position_encoding(x)
        x = tf.layers.dropout(x, 0.1, training=is_training)
        
        for i in range(params['n_hidden_layer']):
            with tf.variable_scope('attn_%d'%i, reuse=reuse):
                x = self_attention(x, is_training)
            with tf.variable_scope('ffn_%d'%i, reuse=reuse):
                x = ffn(x)
        
        logits = tf.layers.dense(x, params['vocab_size'])
    return logits

# %%
def beam_search_decoding():
    batch_size = 1
    initial_ids = tf.constant(params['char2idx']['<start>'], tf.int32, [batch_size])
    
    def symbols_to_logits(ids):
        logits = forward(ids, reuse=True, is_training=False)
        return logits[:, tf.shape(ids)[1]-1, :]
    
    final_ids, final_probs = beam_search.beam_search(
        symbols_to_logits,
        initial_ids,
        params['beam_size'],
        params['seq_len'],
        params['vocab_size'],
        0.0,
        eos_id = params['char2idx']['<end>'])
    
    return final_ids[0, 0, :]

# %%
ints, params['char2idx'] = parse_text('../temp/anna.txt')
params['vocab_size'] = len(params['char2idx'])
params['idx2char'] = {i: c for c, i in params['char2idx'].items()}
print('Vocabulary size:', params['vocab_size'])

X = input_fn(ints)
logits = forward(start_sent(X), reuse=False, is_training=True)

ops = {}
ops['global_step'] = tf.Variable(0, trainable=False)

targets = end_sent(X)
ops['loss'] = tf.reduce_mean(tf.contrib.seq2seq.sequence_loss(
    logits = logits,
    targets = targets,
    weights = tf.to_float(tf.ones_like(targets))))

ops['train'] = tf.train.AdamOptimizer().minimize(ops['loss'], global_step=ops['global_step'])

ops['generate'] = beam_search_decoding()
# Out:
# Vocabulary size: 86

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
while True:
    try:
        _, step, loss = sess.run([ops['train'], ops['global_step'], ops['loss']])
    except tf.errors.OutOfRangeError:
        break
    else:
        if step % params['display_step'] == 0 or step == 1:
            print("Step %d | Loss %.3f" % (step, loss))
        if step % params['generate_step'] == 0 and step > 1:
            ints = sess.run(ops['generate'])
            print('\n'+''.join([params['idx2char'][i] for i in ints])+'\n')
# Out:
# Step 1 | Loss 5.045
# Step 10 | Loss 2.873
# Step 20 | Loss 2.677
# Step 30 | Loss 2.587
# Step 40 | Loss 2.536
# Step 50 | Loss 2.495
# Step 60 | Loss 2.463
# Step 70 | Loss 2.437
# Step 80 | Loss 2.416
# Step 90 | Loss 2.404
# Step 100 | Loss 2.384
#
# <start>in his his his his he his his his his his his his his his his his his his his he his his his his his his his his his his his his his his his his he his he his his his his his his his his he his his h<end>
#
# Step 110 | Loss 2.367
# Step 120 | Loss 2.348
# Step 130 | Loss 2.322
# Step 140 | Loss 2.296
# Step 150 | Loss 2.271
# Step 160 | Loss 2.254
# Step 170 | Loss 2.234
# Step 180 | Loss 2.201
# Step 190 | Loss 2.194
# Step 200 | Loss 2.144
#
# <start>and this his his his his his his, his his his his his his his his his his his his, his his his his his his his his his his his his his his his his his his his his his his his hat his his his his his h
#
# Step 210 | Loss 2.114
# Step 220 | Loss 2.089
# Step 230 | Loss 2.057
# Step 240 | Loss 2.043
# Step 250 | Loss 2.023
# Step 260 | Loss 1.978
# Step 270 | Loss 1.939
# Step 280 | Loss 1.915
# Step 290 | Loss 1.892
# Step 300 | Loss 1.850
#
# <start>the and ther father. And the he he lis linghe lis linght his pof his his his his
# wis his his his his his his cked his his his his
# falis his his his his his his his his life his his
# quis his his his l<end>
#
# Step 310 | Loss 1.819
# Step 320 | Loss 1.790
# Step 330 | Loss 1.786
# Step 340 | Loss 1.744
# Step 350 | Loss 1.714
# Step 360 | Loss 1.689
# Step 370 | Loss 1.660
# Step 380 | Loss 1.629
# Step 390 | Loss 1.626
# Step 400 | Loss 1.584
#
# <start> the was was as alreding aing to to thim, and, and the
# thatter was ays ays aid, was asid aing aing aing tout to to this acof tactre, and and and
# the fatheror factact, wh was was alreaing aing tong way
#
# Step 410 | Loss 1.577
# Step 420 | Loss 1.537
# Step 430 | Loss 1.527
# Step 440 | Loss 1.500
# Step 450 | Loss 1.480
# Step 460 | Loss 1.474
# Step 470 | Loss 1.449
# Step 480 | Loss 1.428
# Step 490 | Loss 1.399
# Step 500 | Loss 1.389
#
# <start> the was to to gand," said, Matvey; "but t the she said, " the said, said, stil
# hought she shought shere shought shought sekings," said, Stepan
# Arkadyev<end><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Step 510 | Loss 1.382
# Step 520 | Loss 1.354
# Step 530 | Loss 1.324
# Step 540 | Loss 1.307
# Step 550 | Loss 1.285
# Step 560 | Loss 1.282
# Step 570 | Loss 1.258
# Step 580 | Loss 1.237
# Step 590 | Loss 1.232
# Step 600 | Loss 1.198
#
# <start>the was aimpossssible, and and and certing to the the sandstings,
# theys was could tome be to to be for him, and as and and ceptrtivaly to him, and
# bechat was as to to go the gove. I dowhat to do that
#
# Step 610 | Loss 1.198
# Step 620 | Loss 1.170
# Step 630 | Loss 1.158
# Step 640 | Loss 1.127
# Step 650 | Loss 1.131
# Step 660 | Loss 1.115
# Step 670 | Loss 1.105
# Step 680 | Loss 1.086
# Step 690 | Loss 1.050
# Step 700 | Loss 1.043
#
# <start> the children, he he was as dimed aked ther bout ff ther.
#
#
# "Matvey with ch shild. Stepan Arkadyevitch his sighed. "That means that she's not slept again all
# night," he thought.
#
# "Well, is she cheerfu
#
# Step 710 | Loss 1.022
# Step 720 | Loss 1.016
# Step 730 | Loss 1.008
# Step 740 | Loss 0.989
# Step 750 | Loss 0.991
# Step 760 | Loss 0.988
# Step 770 | Loss 0.970
# Step 780 | Loss 0.968
# Step 790 | Loss 0.954
# Step 800 | Loss 0.957
#
# <start>her face, tonce alle the stimelfff ace, and and whow s alking wing with wath s thead sat them, aking and her hand
# befrom he bushe face the was as the alam, and or.
#
# "Dolly!" he said, and he at goner.<end>
#
# Step 810 | Loss 0.963
# Step 820 | Loss 0.937
# Step 830 | Loss 0.935
# Step 840 | Loss 0.936
# Step 850 | Loss 0.919
# Step 860 | Loss 0.907
# Step 870 | Loss 0.896
# Step 880 | Loss 0.910
# Step 890 | Loss 0.903
# Step 900 | Loss 0.882
#
# <start>ing her husband tof the voice. "And I was don't he lover my thineses, withought.
#
#
# "Dollly!" he said, sobbing now; "for mercy's sake think of the children;
# they are not to blame! I am to blame, and pu
#
# Step 910 | Loss 0.877
# Step 920 | Loss 0.873
# Step 930 | Loss 0.871
# Step 940 | Loss 0.854
# Step 950 | Loss 0.856
# Step 960 | Loss 0.844
# Step 970 | Loss 0.844
# Step 980 | Loss 0.843
# Step 990 | Loss 0.829
# Step 1000 | Loss 0.847
#
# <start>ing his paper and drinking his coffee; but when he saw
# her tortured, suffering face, heard the tone of her voice, submissive to
# fate and full of despair, there was a catch in his breath and a lump in
#
#
# Step 1010 | Loss 0.827
# Step 1020 | Loss 0.814
# Step 1030 | Loss 0.807
# Step 1040 | Loss 0.792
# Step 1050 | Loss 0.802
# Step 1060 | Loss 0.789
# Step 1070 | Loss 0.807
# Step 1080 | Loss 0.799
# Step 1090 | Loss 0.766
# Step 1100 | Loss 0.786
#
# <start> the board, Stepan Arkadyevitch, and with good a onced ating him of the
# was ays tand talook rd herooom.
#
# Stepan Arkadyevitc<end><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Step 1110 | Loss 0.793
# Step 1120 | Loss 0.766
# Step 1130 | Loss 0.759
# Step 1140 | Loss 0.759
# Step 1150 | Loss 0.756
# Step 1160 | Loss 0.752
# Step 1170 | Loss 0.743
# Step 1180 | Loss 0.748
# Step 1190 | Loss 0.739
# Step 1200 | Loss 0.735
#
# <start> the board, Stepan Arkadyevitch, and with his pecial
# quencking ored. It his he hand his good-humored deference. Stepan Arkadyevitch, escorted by a
# deferential porter with a portfolio, went into his li
#
# Step 1210 | Loss 0.733
# Step 1220 | Loss 0.753
# Step 1230 | Loss 0.759
# Step 1240 | Loss 0.750
# Step 1250 | Loss 0.747
# Step 1260 | Loss 0.732
# Step 1270 | Loss 0.736
# Step 1280 | Loss 0.723
# Step 1290 | Loss 0.728
# Step 1300 | Loss 0.718
#
# <start> was in his blood, in
# virtue of which he treated all men perfectly equally and exactly the
# same, whatever their fortune or calling might be; and thirdly--the most
# important point--his complete indifff
#
# Step 1310 | Loss 0.717
# Step 1320 | Loss 0.718
# Step 1330 | Loss 0.708
# Step 1340 | Loss 0.720
# Step 1350 | Loss 0.703
# Step 1360 | Loss 0.692
# Step 1370 | Loss 0.688
# Step 1380 | Loss 0.686
# Step 1390 | Loss 0.692
# Step 1400 | Loss 0.676
#
# <start> the board, Stepan Arkadyevitch, escorted by a
# deferential porter with a portfolio, went into his little private room,
# put on his uniform, and went into the boardroom. The clerks and copyists
# all rose
#
# Step 1410 | Loss 0.672
# Step 1420 | Loss 0.690
# Step 1430 | Loss 0.681
# Step 1440 | Loss 0.678
# Step 1450 | Loss 0.683
# Step 1460 | Loss 0.691
# Step 1470 | Loss 0.685
# Step 1480 | Loss 0.670
# Step 1490 | Loss 0.672
# Step 1500 | Loss 0.665
#
# <start> the of the legant Grinevitch, which
# had such long known becauteses, and he were in him.
#
# "We he have long?"
#
# "I have juse, come, and very much you," said Stepan Arkadyevitch, gave and to the
# splaced
#
# Step 1510 | Loss 0.656
# Step 1520 | Loss 0.649
# Step 1530 | Loss 0.642
# Step 1540 | Loss 0.648
# Step 1550 | Loss 0.645
# Step 1560 | Loss 0.639
# Step 1570 | Loss 0.650
# Step 1580 | Loss 0.669
# Step 1590 | Loss 0.662
# Step 1600 | Loss 0.638
#
# <start> was that Oblonsky, as he was doing the same as every one did,
# laughed complacently and good-humoredly, while Levin laughed without
# complacency and sometimes angrily.
#
# "We have long been expect<end><pad><pad><pad><pad><pad><pad>
#
# Step 1610 | Loss 0.639
# Step 1620 | Loss 0.623
# Step 1630 | Loss 0.638
# Step 1640 | Loss 0.634
# Step 1650 | Loss 0.643
# Step 1660 | Loss 0.640
# Step 1670 | Loss 0.634
# Step 1680 | Loss 0.631
# Step 1690 | Loss 0.657
# Step 1700 | Loss 0.640
#
# <start> was that Oblonsky, as he was doing the same as every one did,
# laughed complacently and good-humoredly, while Levin laughed without
# complacency and sometimes angrily.
#
# "We have long been expecting yo<end>
#
# Step 1710 | Loss 0.653
# Step 1720 | Loss 0.633
# Step 1730 | Loss 0.629
# Step 1740 | Loss 0.622
# Step 1750 | Loss 0.638
# Step 1760 | Loss 0.642
# Step 1770 | Loss 0.648
# Step 1780 | Loss 0.645
# Step 1790 | Loss 0.650
# Step 1800 | Loss 0.643
#
# <start>he were work."
#
# "Welll, said Levin was in love, and loke about what it the Shtcherbatsky in the sprofessor of French
# literati<end><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# Step 1810 | Loss 0.643
# Step 1820 | Loss 0.624
# Step 1830 | Loss 0.628
# Step 1840 | Loss 0.618
# Step 1850 | Loss 0.639
# Step 1860 | Loss 0.632
# Step 1870 | Loss 0.646
# Step 1880 | Loss 0.642
# Step 1890 | Loss 0.640
# Step 1900 | Loss 0.619
#
# <start>ing," responded Oblonsky. "We'll talk it over. But what's
# brought you up to town?"
#
# "Oh, we'll talk about that, too, later on," said Levin, reddening again
# up to his ears.
#
# "All right. I seemed <end><pad><pad><pad><pad><pad>
#
# Step 1910 | Loss 0.621
# Step 1920 | Loss 0.612
# Step 1930 | Loss 0.620
# Step 1940 | Loss 0.606
# Step 1950 | Loss 0.600
# Step 1960 | Loss 0.625
# Step 1970 | Loss 0.602
# Step 1980 | Loss 0.606
# Step 1990 | Loss 0.616
# Step 2000 | Loss 0.612
#
# <start>in them, but under the
# poetical veil that shrouded them he assumed the existence of the
# loftiest sentiments and every possible perfection. Why it was the three
# young ladies had one day to speak French
